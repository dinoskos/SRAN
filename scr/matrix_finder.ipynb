# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# %%
current_dir = os.getcwd()
project_dir = os.path.dirname(current_dir)

# Loading rule specification
data_dir = os.path.join(project_dir, 'data', 'raw_data_2.xlsx')

# Loading complex matrices excel rule list
single_dir = os.path.join(project_dir, 'rule_output', 'in_out_single.xlsx')
four_dir = os.path.join(project_dir, 'rule_output', 'in_out_four.xlsx')
left_right_dir = os.path.join(project_dir, 'rule_output', 'left_right_single.xlsx')
up_down_dir = os.path.join(project_dir, 'rule_output', 'up_down.xlsx')

# %%
data_spec = pd.read_excel(data_dir, sheet_name='Scoring Key')

single_df = pd.read_excel(single_dir)
four_df = pd.read_excel(four_dir)
left_right_df = pd.read_excel(left_right_dir)
up_down_df = pd.read_excel(up_down_dir)

# %%
# Step 2: Standardize terminology in data_spec to match the matrix files
def standardize_term(x):
    if isinstance(x, str):
        x = x.strip()
        replacements = {
            "Distributed Three": "Distribute_Three",
            "Arithmetic": "Arithmetic",
            "Distribute Three": "Distribute_Three"
        }
        return replacements.get(x, x)
    return x

for col in ['Type_0', 'Size_0', 'Type_1', 'Size_1']:
    data_spec[col] = data_spec[col].apply(standardize_term)

# %%
# Step 2: Create a mapping from design to dataframe
design_to_df = {
    'In_Out_Center_Single': single_df,
    'In_Out_Distribute_Four': four_df,
    'Left_Right_Single': left_right_df,
    'Up_Down_Single': up_down_df
}

# %%
# Store eligible results
eligible_sources = []

for idx, row in data_spec.iterrows():
    design = row['Design']
    df = design_to_df.get(design)

    if df is not None:
        filtered = df[
            (df['Number_0'] == 'Constant') &
            (df['Position_0'] == 'Constant') &
            (df['Number_1'] == 'Constant') &
            (df['Position_1'] == 'Constant') &
            (df['Color_0'] == 'Constant') &
            (df['Color_1'] == 'Constant') &
            (df['Type_0'] == row['Type_0']) &
            (df['Size_0'] == row['Size_0']) &
            (df['Type_1'] == row['Type_1']) &
            (df['Size_1'] == row['Size_1'])
        ]
        names = filtered['Name'].tolist()
        eligible_sources.append(names)
    else:
        eligible_sources.append([])

# Update and display result
result_df = data_spec.copy()
result_df['Source_file'] = eligible_sources

# %%
result_df.head(1)
# Out:
#    ID                  Design Numer/Position_0            Type_0  \
# 0  17  In_Out_Distribute_Four         Constant  Distribute_Three
#
#              Size_0   Color_0 Number/Position_1            Type_1      Size_1  \
# 0  Distribute_Three  Constant          Constant  Distribute_Three  Arithmetic
#
#     Color_1                                        Source_file  \
# 0  Constant  [RAVEN_11284_train, RAVEN_11558_test, RAVEN_12...
#
#         File_Name Correct Option Reece's Comments  New_Item  \
# 0  IOF_Dt_Dt_Dt_A       choice_6             Easy       NaN
#
#    New Correct Choice
# 0                 NaN

# %%
# === Plotting functions ===
def save_problem_grid(image, filename):
    fig = plt.figure(figsize=(10, 10))
    for i in range(8):
        ax = plt.subplot(3, 3, i + 1)
        ax.imshow(image[i], cmap='gray')
        ax.axis('off')
        rect = Rectangle((0, 0), 1, 1, transform=ax.transAxes, color='gray', fill=False, lw=1.8)
        ax.add_patch(rect)
    ax = plt.subplot(3, 3, 9)
    ax.text(0.5, 0.5, '?', fontsize=40, ha='center', va='center')
    ax.axis('off')
    rect = Rectangle((0, 0), 1, 1, transform=ax.transAxes, color='gray', fill=False, lw=1.8)
    ax.add_patch(rect)
    plt.subplots_adjust(wspace=0.1, hspace=0.1)
    plt.savefig(filename)
    plt.close(fig)

def save_choices_plot(image, target, filename):
    fig = plt.figure(figsize=(12, 6))
    for i in range(8, 16):
        ax = plt.subplot(2, 4, i - 7)
        ax.set_title(f"Choice {i - 7}")
        ax.imshow(image[i], cmap='gray')
        ax.axis('off')
        rect = Rectangle((0, 0), 1, 1, transform=ax.transAxes, color='gray', fill=False, lw=1.8)
        ax.add_patch(rect)
    plt.subplots_adjust(wspace=0.1, hspace=0.3)
    plt.savefig(filename)
    plt.close(fig)

# %%
output_folder = 'image'
os.makedirs(output_folder, exist_ok=True)

# Make a copy of result_df to update
updated_result_df = result_df.copy()

for idx, row in updated_result_df.iterrows():
    file_base = row['File_Name']
    design = row['Design']
    source_files = row['Source_file']

    if not isinstance(source_files, list) or len(source_files) == 0:
        continue

    correct_options = []

    for i, file_name in enumerate(source_files):
        if not file_name.endswith('.npz'):
            file_name += '.npz'

        # === Build full path ===
        project_dir = os.path.dirname(os.getcwd())
        design_paths = {
            'In_Out_Center_Single': 'output/in_center_single_out_center_single',
            'In_Out_Distribute_Four': 'output/in_distribute_four_out_center_single',
            'Left_Right_Single': 'output/left_center_single_right_center_single',
            'Up_Down_Single': 'output/up_center_single_down_center_single',
        }

        folder = design_paths.get(design)
        if not folder:
            print(f"Design {design} not recognized. Skipping row {idx}.")
            continue

        npz_path = os.path.join(project_dir, folder, file_name)
        if not os.path.exists(npz_path):
            print(f"File not found: {npz_path}")
            continue

        # === Load and extract target ===
        data = np.load(npz_path)
        image = data['image']
        target = int(data['target'])  # Ensure it's a scalar int
        correct_options.append(target)

        # === Render and save ===
        if len(source_files) == 1:
            output_name = f"{file_base}_val.png"
        else:
            output_name = f"{file_base}_val_{i}.png"

        save_path = os.path.join(output_folder, output_name)

        # Temp save
        os.makedirs("temp_img", exist_ok=True)
        problem_grid_path = "temp_img/problem_grid.png"
        choices_plot_path = "temp_img/choices_plot.png"

        save_problem_grid(image, problem_grid_path)
        save_choices_plot(image, target, choices_plot_path)

        # Combine images
        from PIL import Image
        problem_grid = Image.open(problem_grid_path)
        choices_plot = Image.open(choices_plot_path)

        combined_width = max(problem_grid.width, choices_plot.width)
        combined_height = problem_grid.height + choices_plot.height

        combined_image = Image.new("RGB", (combined_width, combined_height), (255, 255, 255))
        combined_image.paste(problem_grid, ((combined_width - problem_grid.width) // 2, 0))
        combined_image.paste(choices_plot, ((combined_width - choices_plot.width) // 2, problem_grid.height))

        combined_image.save(save_path)

    # === Update the correct option column in result_df ===
    if len(correct_options) == 1:
        updated_result_df.at[idx, 'Correct Option'] = correct_options[0]
    else:
        updated_result_df.at[idx, 'Correct Option'] = correct_options

# %%
updated_result_df
# Out:
#     ID                  Design Numer/Position_0            Type_0  \
# 0   17  In_Out_Distribute_Four         Constant  Distribute_Three
# 1   12  In_Out_Distribute_Four         Constant  Distribute_Three
# 2   10  In_Out_Distribute_Four         Constant  Distribute_Three
# 3   21  In_Out_Distribute_Four         Constant  Distribute_Three
# 4   15  In_Out_Distribute_Four         Constant  Distribute_Three
# 5   20  In_Out_Distribute_Four         Constant  Distribute_Three
# 6    9  In_Out_Distribute_Four         Constant       Progression
# 7   19  In_Out_Distribute_Four         Constant       Progression
# 8   16  In_Out_Distribute_Four         Constant       Progression
# 9   11  In_Out_Distribute_Four         Constant       Progression
# 10  13    In_Out_Center_Single         Constant  Distribute_Three
# 11   4    In_Out_Center_Single         Constant  Distribute_Three
# 12  23    In_Out_Center_Single         Constant  Distribute_Three
# 13   2    In_Out_Center_Single         Constant  Distribute_Three
# 14   7    In_Out_Center_Single         Constant  Distribute_Three
# 15   5    In_Out_Center_Single         Constant       Progression
# 16  14    In_Out_Center_Single         Constant       Progression
# 17   6    In_Out_Center_Single         Constant       Progression
# 18   1    In_Out_Center_Single         Constant       Progression
# 19  22    In_Out_Center_Single         Constant       Progression
# 20  18    In_Out_Center_Single         Constant       Progression
# 21   8    In_Out_Center_Single         Constant       Progression
# 22   3    In_Out_Center_Single         Constant       Progression
# 23  24       Left_Right_Single         Constant  Distribute_Three
# 24  35       Left_Right_Single         Constant  Distribute_Three
# 25  29       Left_Right_Single         Constant  Distribute_Three
# 26  27       Left_Right_Single         Constant  Distribute_Three
# 27  26       Left_Right_Single         Constant  Distribute_Three
# 28  30       Left_Right_Single         Constant  Distribute_Three
# 29  33       Left_Right_Single         Constant       Progression
# 30  28       Left_Right_Single         Constant       Progression
# 31  31       Left_Right_Single         Constant       Progression
# 32  25       Left_Right_Single         Constant       Progression
# 33  34       Left_Right_Single         Constant       Progression
# 34  32       Left_Right_Single         Constant       Progression
# 35  36       Left_Right_Single         Constant       Progression
# 36  37          Up_Down_Single         Constant  Distribute_Three
# 37  48          Up_Down_Single         Constant  Distribute_Three
# 38  42          Up_Down_Single         Constant  Distribute_Three
# 39  40          Up_Down_Single         Constant  Distribute_Three
# 40  43          Up_Down_Single         Constant  Distribute_Three
# 41  39          Up_Down_Single         Constant  Distribute_Three
# 42  50          Up_Down_Single         Constant  Distribute_Three
# 43  46          Up_Down_Single         Constant       Progression
# 44  41          Up_Down_Single         Constant       Progression
# 45  38          Up_Down_Single         Constant       Progression
# 46  44          Up_Down_Single         Constant       Progression
# 47  47          Up_Down_Single         Constant       Progression
# 48  45          Up_Down_Single         Constant       Progression
# 49  49          Up_Down_Single         Constant       Progression
#
#               Size_0   Color_0 Number/Position_1            Type_1  \
# 0   Distribute_Three  Constant          Constant  Distribute_Three
# 1   Distribute_Three  Constant          Constant       Progression
# 2        Progression  Constant          Constant  Distribute_Three
# 3        Progression  Constant          Constant  Distribute_Three
# 4        Progression  Constant          Constant       Progression
# 5        Progression  Constant          Constant       Progression
# 6   Distribute_Three  Constant          Constant       Progression
# 7        Progression  Constant          Constant       Progression
# 8        Progression  Constant          Constant       Progression
# 9        Progression  Constant          Constant       Progression
# 10  Distribute_Three  Constant          Constant  Distribute_Three
# 11  Distribute_Three  Constant          Constant       Progression
# 12       Progression  Constant          Constant  Distribute_Three
# 13       Progression  Constant          Constant  Distribute_Three
# 14       Progression  Constant          Constant       Progression
# 15  Distribute_Three  Constant          Constant  Distribute_Three
# 16  Distribute_Three  Constant          Constant  Distribute_Three
# 17  Distribute_Three  Constant          Constant  Distribute_Three
# 18  Distribute_Three  Constant          Constant       Progression
# 19       Progression  Constant          Constant  Distribute_Three
# 20       Progression  Constant          Constant  Distribute_Three
# 21       Progression  Constant          Constant       Progression
# 22       Progression  Constant          Constant       Progression
# 23        Arithmetic  Constant          Constant  Distribute_Three
# 24        Arithmetic  Constant          Constant  Distribute_Three
# 25        Arithmetic  Constant          Constant       Progression
# 26        Arithmetic  Constant          Constant       Progression
# 27  Distribute_Three  Constant          Constant       Progression
# 28       Progression  Constant          Constant  Distribute_Three
# 29        Arithmetic  Constant          Constant  Distribute_Three
# 30        Arithmetic  Constant          Constant  Distribute_Three
# 31        Arithmetic  Constant          Constant  Distribute_Three
# 32        Arithmetic  Constant          Constant       Progression
# 33  Distribute_Three  Constant          Constant  Distribute_Three
# 34  Distribute_Three  Constant          Constant       Progression
# 35       Progression  Constant          Constant       Progression
# 36        Arithmetic  Constant          Constant  Distribute_Three
# 37        Arithmetic  Constant          Constant  Distribute_Three
# 38        Arithmetic  Constant          Constant       Progression
# 39        Arithmetic  Constant          Constant       Progression
# 40  Distribute_Three  Constant          Constant  Distribute_Three
# 41  Distribute_Three  Constant          Constant       Progression
# 42       Progression  Constant          Constant  Distribute_Three
# 43        Arithmetic  Constant          Constant  Distribute_Three
# 44        Arithmetic  Constant          Constant  Distribute_Three
# 45        Arithmetic  Constant          Constant       Progression
# 46        Arithmetic  Constant          Constant       Progression
# 47  Distribute_Three  Constant          Constant  Distribute_Three
# 48  Distribute_Three  Constant          Constant       Progression
# 49  Distribute_Three  Constant          Constant       Progression
#
#               Size_1   Color_1  \
# 0         Arithmetic  Constant
# 1         Arithmetic  Constant
# 2   Distribute_Three  Constant
# 3        Progression  Constant
# 4   Distribute_Three  Constant
# 5        Progression  Constant
# 6         Arithmetic  Constant
# 7         Arithmetic  Constant
# 8   Distribute_Three  Constant
# 9        Progression  Constant
# 10        Arithmetic  Constant
# 11       Progression  Constant
# 12        Arithmetic  Constant
# 13  Distribute_Three  Constant
# 14  Distribute_Three  Constant
# 15        Arithmetic  Constant
# 16  Distribute_Three  Constant
# 17       Progression  Constant
# 18        Arithmetic  Constant
# 19        Arithmetic  Constant
# 20  Distribute_Three  Constant
# 21  Distribute_Three  Constant
# 22       Progression  Constant
# 23        Arithmetic  Constant
# 24  Distribute_Three  Constant
# 25  Distribute_Three  Constant
# 26       Progression  Constant
# 27        Arithmetic  Constant
# 28       Progression  Constant
# 29        Arithmetic  Constant
# 30  Distribute_Three  Constant
# 31       Progression  Constant
# 32  Distribute_Three  Constant
# 33       Progression  Constant
# 34        Arithmetic  Constant
# 35       Progression  Constant
# 36        Arithmetic  Constant
# 37  Distribute_Three  Constant
# 38  Distribute_Three  Constant
# 39       Progression  Constant
# 40  Distribute_Three  Constant
# 41        Arithmetic  Constant
# 42  Distribute_Three  Constant
# 43        Arithmetic  Constant
# 44  Distribute_Three  Constant
# 45  Distribute_Three  Constant
# 46       Progression  Constant
# 47       Progression  Constant
# 48        Arithmetic  Constant
# 49       Progression  Constant
#
#                                           Source_file       File_Name  \
# 0   [RAVEN_11284_train, RAVEN_11558_test, RAVEN_12...  IOF_Dt_Dt_Dt_A
# 1   [RAVEN_1190_train, RAVEN_12633_train, RAVEN_14...   IOF_Dt_Dt_P_A
# 2   [RAVEN_10906_val, RAVEN_11461_train, RAVEN_114...  IOF_Dt_P_Dt_Dt
# 3                 [RAVEN_10887_val, RAVEN_6945_train]   IOF_Dt_P_Dt_P
# 4   [RAVEN_11643_train, RAVEN_14524_train, RAVEN_2...   IOF_Dt_P_P_Dt
# 5   [RAVEN_11088_test, RAVEN_3900_train, RAVEN_462...    IOF_Dt_P_P_P
# 6   [RAVEN_10390_train, RAVEN_2909_test, RAVEN_342...    IOF_P_Dt_P_A
# 7   [RAVEN_14264_train, RAVEN_3053_train, RAVEN_45...     IOF_P_P_P_A
# 8   [RAVEN_1646_val, RAVEN_2170_train, RAVEN_8771_...    IOF_P_P_P_Dt
# 9   [RAVEN_14670_train, RAVEN_5786_val, RAVEN_8115...     IOF_P_P_P_P
# 10  [RAVEN_1496_val, RAVEN_1645_train, RAVEN_1875_...  IOS_Dt_Dt_Dt_A
# 11  [RAVEN_1017_val, RAVEN_1164_train, RAVEN_1518_...   IOS_Dt_Dt_P_P
# 12  [RAVEN_1194_train, RAVEN_1490_train, RAVEN_160...   IOS_Dt_P_Dt_A
# 13  [RAVEN_1265_train, RAVEN_1640_train, RAVEN_227...  IOS_Dt_P_Dt_Dt
# 14  [RAVEN_2029_test, RAVEN_2439_test, RAVEN_3192_...   IOS_Dt_P_P_Dt
# 15  [RAVEN_1182_train, RAVEN_1390_train, RAVEN_241...   IOS_P_Dt_Dt_A
# 16  [RAVEN_1207_val, RAVEN_1368_test, RAVEN_201_tr...  IOS_P_Dt_Dt_Dt
# 17  [RAVEN_1011_train, RAVEN_1066_val, RAVEN_1131_...   IOS_P_Dt_Dt_P
# 18  [RAVEN_1028_test, RAVEN_106_val, RAVEN_1128_te...    IOS_P_Dt_P_A
# 19  [RAVEN_1230_train, RAVEN_1792_train, RAVEN_304...    IOS_P_P_Dt_A
# 20  [RAVEN_1283_train, RAVEN_1372_train, RAVEN_138...   IOS_P_P_Dt_Dt
# 21  [RAVEN_1808_test, RAVEN_3162_train, RAVEN_345_...    IOS_P_P_P_Dt
# 22  [RAVEN_1202_train, RAVEN_1407_val, RAVEN_1662_...     IOS_P_P_P_P
# 23  [RAVEN_12624_train, RAVEN_14001_train, RAVEN_1...    LR_Dt_A_Dt_A
# 24  [RAVEN_1030_train, RAVEN_14343_train, RAVEN_17...   LR_Dt_A_Dt_Dt
# 25  [RAVEN_12940_train, RAVEN_2436_val, RAVEN_345_...    LR_Dt_A_P_Dt
# 26                                 [RAVEN_14338_test]     LR_Dt_A_P_P
# 27  [RAVEN_1061_train, RAVEN_1207_val, RAVEN_12092...    LR_Dt_Dt_P_A
# 28              [RAVEN_10584_train, RAVEN_6803_train]    LR_Dt_P_Dt_P
# 29  [RAVEN_10485_train, RAVEN_13514_train, RAVEN_3...     LR_P_A_Dt_A
# 30  [RAVEN_11083_train, RAVEN_1912_train, RAVEN_28...    LR_P_A_Dt_Dt
# 31  [RAVEN_11289_test, RAVEN_3267_val, RAVEN_5471_...     LR_P_A_Dt_P
# 32  [RAVEN_11848_test, RAVEN_13329_test, RAVEN_167...     LR_P_A_P_Dt
# 33  [RAVEN_12632_train, RAVEN_12893_train, RAVEN_1...    LR_P_Dt_Dt_P
# 34  [RAVEN_10130_train, RAVEN_11238_test, RAVEN_14...     LR_P_Dt_P_A
# 35  [RAVEN_14310_train, RAVEN_5742_train, RAVEN_78...      LR_P_P_P_P
# 36  [RAVEN_12624_train, RAVEN_14001_train, RAVEN_1...    UD_Dt_A_Dt_A
# 37  [RAVEN_1030_train, RAVEN_14343_train, RAVEN_17...   UD_Dt_A_Dt_Dt
# 38  [RAVEN_12940_train, RAVEN_2436_val, RAVEN_345_...    UD_Dt_A_P_Dt
# 39                                 [RAVEN_14338_test]     UD_Dt_A_P_P
# 40  [RAVEN_12773_train, RAVEN_2089_test, RAVEN_220...  UD_Dt_Dt_Dt_Dt
# 41  [RAVEN_1061_train, RAVEN_1207_val, RAVEN_12092...    UD_Dt_Dt_P_A
# 42  [RAVEN_10610_train, RAVEN_11204_train, RAVEN_1...    UD_Dt_P_Dt_A
# 43  [RAVEN_10485_train, RAVEN_13514_train, RAVEN_3...     UD_P_A_Dt_A
# 44  [RAVEN_11083_train, RAVEN_1912_train, RAVEN_28...    UD_P_A_Dt_Dt
# 45  [RAVEN_11848_test, RAVEN_13329_test, RAVEN_167...     UD_P_A_P_Dt
# 46  [RAVEN_1814_train, RAVEN_7382_train, RAVEN_91_...      UD_P_A_P_P
# 47  [RAVEN_12632_train, RAVEN_12893_train, RAVEN_1...    UD_P_Dt_Dt_P
# 48  [RAVEN_10130_train, RAVEN_11238_test, RAVEN_14...     UD_P_Dt_P_A
# 49  [RAVEN_12622_train, RAVEN_2953_train, RAVEN_69...     UD_P_Dt_P_P
#
#                                        Correct Option Reece's Comments  \
# 0                      [6, 2, 6, 2, 2, 0, 2, 0, 7, 0]             Easy
# 1                         [2, 4, 2, 7, 7, 0, 4, 5, 1]         Moderate
# 2                                  [2, 1, 6, 2, 5, 6]             Hard
# 3                                              [4, 5]         Moderate
# 4                                     [4, 6, 0, 4, 6]         Moderate
# 5                                     [2, 4, 6, 4, 7]             Easy
# 6                   [0, 1, 6, 4, 1, 6, 2, 2, 7, 1, 0]         Moderate
# 7                            [4, 0, 2, 2, 5, 0, 3, 4]             Easy
# 8                                           [1, 7, 7]         Moderate
# 9                                           [7, 1, 0]             Hard
# 10  [2, 1, 5, 1, 6, 0, 7, 6, 5, 4, 7, 6, 5, 6, 2, ...             Easy
# 11  [1, 6, 2, 3, 1, 0, 5, 2, 4, 4, 5, 0, 3, 3, 4, ...             Easy
# 12  [2, 4, 7, 0, 5, 6, 7, 7, 7, 7, 6, 0, 0, 6, 3, ...             Easy
# 13  [5, 2, 2, 3, 6, 5, 4, 2, 2, 6, 3, 6, 0, 0, 2, ...         Moderate
# 14               [0, 5, 2, 4, 2, 5, 3, 5, 5, 1, 5, 7]             Hard
# 15  [7, 6, 2, 4, 4, 5, 0, 5, 1, 3, 6, 6, 0, 2, 3, ...             Easy
# 16  [6, 2, 7, 1, 3, 7, 1, 3, 4, 6, 6, 4, 2, 2, 4, ...         Moderate
# 17  [1, 1, 1, 4, 1, 3, 7, 0, 4, 1, 4, 3, 0, 1, 6, ...         Moderate
# 18  [1, 2, 3, 0, 6, 3, 5, 6, 3, 4, 5, 5, 5, 3, 7, ...             Hard
# 19  [4, 5, 0, 4, 2, 7, 6, 6, 6, 1, 7, 4, 6, 1, 0, ...             Hard
# 20  [6, 1, 0, 2, 5, 7, 5, 3, 0, 5, 1, 6, 0, 4, 3, ...             Hard
# 21            [5, 2, 4, 1, 5, 3, 0, 4, 5, 2, 1, 0, 2]         Moderate
# 22  [4, 7, 5, 3, 3, 1, 1, 2, 3, 5, 7, 6, 7, 3, 4, ...         Moderate
# 23            [6, 1, 6, 4, 0, 5, 6, 0, 3, 4, 1, 2, 1]             Hard
# 24                              [5, 4, 3, 1, 0, 4, 4]         Moderate
# 25                        [5, 3, 4, 2, 1, 2, 1, 0, 7]         Moderate
# 26                                                  3             Hard
# 27               [6, 6, 5, 6, 7, 1, 6, 1, 3, 2, 7, 2]             Hard
# 28                                             [7, 2]             Hard
# 29                                    [2, 4, 4, 7, 6]             Hard
# 30                     [1, 1, 7, 5, 3, 7, 3, 3, 1, 6]             Hard
# 31                                          [1, 1, 4]         Moderate
# 32                  [7, 0, 1, 6, 7, 0, 0, 0, 0, 6, 4]         Moderate
# 33                           [3, 5, 3, 4, 4, 5, 2, 0]         Moderate
# 34                  [3, 5, 7, 5, 7, 5, 3, 3, 1, 3, 6]             Hard
# 35                                          [4, 5, 6]             Hard
# 36            [6, 1, 6, 4, 0, 5, 6, 0, 3, 4, 1, 2, 1]             Easy
# 37                              [5, 4, 3, 1, 0, 4, 4]         Moderate
# 38                        [5, 3, 4, 2, 1, 2, 1, 0, 7]             Hard
# 39                                                  3         Moderate
# 40                        [3, 3, 0, 0, 6, 4, 0, 7, 3]             Hard
# 41               [6, 6, 5, 6, 7, 1, 6, 1, 3, 2, 7, 2]             Hard
# 42                                    [3, 3, 7, 5, 1]             Hard
# 43                                    [2, 4, 4, 7, 6]             Easy
# 44                     [1, 1, 7, 5, 3, 7, 3, 3, 1, 6]             Hard
# 45                  [7, 0, 1, 6, 7, 0, 0, 0, 0, 6, 4]             Hard
# 46                                          [1, 4, 7]             Hard
# 47                           [3, 5, 3, 4, 4, 5, 2, 0]         Moderate
# 48                  [3, 5, 7, 5, 7, 5, 3, 3, 1, 3, 6]         Moderate
# 49                                          [0, 6, 6]             Easy
#
#     New_Item  New Correct Choice
# 0        NaN                 NaN
# 1        NaN                 NaN
# 2        NaN                 NaN
# 3        NaN                 NaN
# 4        NaN                 NaN
# 5        NaN                 NaN
# 6        NaN                 NaN
# 7        NaN                 NaN
# 8        NaN                 NaN
# 9        NaN                 NaN
# 10       NaN                 NaN
# 11       NaN                 NaN
# 12       NaN                 NaN
# 13       NaN                 NaN
# 14       NaN                 NaN
# 15       NaN                 NaN
# 16       NaN                 NaN
# 17       NaN                 NaN
# 18       NaN                 NaN
# 19       NaN                 NaN
# 20       NaN                 NaN
# 21       NaN                 NaN
# 22       NaN                 NaN
# 23       NaN                 NaN
# 24       NaN                 NaN
# 25       NaN                 NaN
# 26       NaN                 NaN
# 27       NaN                 NaN
# 28       NaN                 NaN
# 29       NaN                 NaN
# 30       NaN                 NaN
# 31       NaN                 NaN
# 32       NaN                 NaN
# 33       NaN                 NaN
# 34       NaN                 NaN
# 35       NaN                 NaN
# 36       NaN                 NaN
# 37       NaN                 NaN
# 38       NaN                 NaN
# 39       NaN                 NaN
# 40       NaN                 NaN
# 41       NaN                 NaN
# 42       NaN                 NaN
# 43       NaN                 NaN
# 44       NaN                 NaN
# 45       NaN                 NaN
# 46       NaN                 NaN
# 47       NaN                 NaN
# 48       NaN                 NaN
# 49       NaN                 NaN

# %%
updated_result_df.to_excel('result.xlsx')
